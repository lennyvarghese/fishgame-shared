# %%
import hddm
import numpy as np
import pandas
from matplotlib import pyplot as plt

% matplotlib notebook

# %%
audio_v = hddm.load('audio_quick_accuracy_vC_zS_a_t/model_1.pkl')
audio_v_a = hddm.load('audio_quick_accuracy_vC_zS_aC_t/model_1.pkl')
audio_v_z = hddm.load('audio_quick_accuracy_vC_zSC_a_t/model_1.pkl')
audio_a_z = hddm.load('audio_quick_accuracy_v_zSC_aC_t/model_1.pkl')
audio_v_a_z = hddm.load('audio_quick_accuracy_vC_zSC_aC_t/model_1.pkl')
audio_null = hddm.load('audio_quick_accuracy_v_zS_a_t/model_1.pkl')
# Out:
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.

# %%
visual_v = hddm.load('visual_quick_accuracy_vC_zS_a_t/model_1.pkl')
visual_v_a = hddm.load('visual_quick_accuracy_vC_zS_aC_t/model_1.pkl')
visual_v_z = hddm.load('visual_quick_accuracy_vC_zSC_a_t/model_1.pkl')
visual_a_z = hddm.load('visual_quick_accuracy_v_zSC_aC_t/model_1.pkl')
visual_v_a_z = hddm.load('visual_quick_accuracy_vC_zSC_aC_t/model_1.pkl')
visual_null = hddm.load('visual_quick_accuracy_v_zS_a_t/model_1.pkl')
# Out:
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.

# %% [markdown]
# ## Visual v ~ congruence

# %%
print(visual_v.dic)
visual_v.plot_posteriors('v_Intercept')
visual_v.plot_posteriors('v_C(condition, Treatment("control"))[T.congruent]')
visual_v.plot_posteriors('v_C(condition, Treatment("control"))[T.incongruent]')
visual_v.plot_posteriors('z_Intercept')
visual_v.plot_posteriors('a_Intercept')
visual_v.plot_posteriors('t_Intercept')
# Out:
# -34368.17778
# Plotting v_Intercept
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.congruent]
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.incongruent]
# <img src="data:image/png;base64,...">
# Plotting z_Intercept
# <img src="data:image/png;base64,...">
# Plotting a_Intercept
# <img src="data:image/png;base64,...">
# Plotting t_Intercept
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Visual, v, z ~ congruence

# %%
print(visual_v_z.dic)
visual_v_z.plot_posteriors('v_Intercept')
visual_v_z.plot_posteriors('v_C(condition, Treatment("control"))[T.congruent]')
visual_v_z.plot_posteriors('v_C(condition, Treatment("control"))[T.incongruent]')
visual_v_z.plot_posteriors('z_Intercept')
visual_v_z.plot_posteriors('z_C(condition, Treatment("control"))[T.congruent]')
visual_v_z.plot_posteriors('z_C(condition, Treatment("control"))[T.incongruent]')
visual_v_z.plot_posteriors('a_Intercept')
visual_v_z.plot_posteriors('t_Intercept')
# Out:
# nan
# Plotting v_Intercept
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.congruent]
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.incongruent]
# <img src="data:image/png;base64,...">
# Plotting z_Intercept
# <img src="data:image/png;base64,...">
# Plotting z_C(condition, Treatment("control"))[T.congruent]
# <img src="data:image/png;base64,...">
# Plotting z_C(condition, Treatment("control"))[T.incongruent]
# <img src="data:image/png;base64,...">
# Plotting a_Intercept
# <img src="data:image/png;base64,...">
# Plotting t_Intercept
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Visual, v, a, z ~ congruence

# %%
print(visual_v_a_z.dic)
visual_v_a_z.plot_posteriors('v_Intercept')
visual_v_a_z.plot_posteriors('v_C(condition, Treatment("control"))[T.congruent]')
visual_v_a_z.plot_posteriors('v_C(condition, Treatment("control"))[T.incongruent]')
visual_v_a_z.plot_posteriors('z_Intercept')
visual_v_a_z.plot_posteriors('z_C(condition, Treatment("control"))[T.congruent]')
visual_v_a_z.plot_posteriors('z_C(condition, Treatment("control"))[T.incongruent]')
visual_v_a_z.plot_posteriors('a_Intercept')
visual_v_a_z.plot_posteriors('t_Intercept')
# Out:
# nan
# Plotting v_Intercept
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.congruent]
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.incongruent]
# <img src="data:image/png;base64,...">
# Plotting z_Intercept
# <img src="data:image/png;base64,...">
# Plotting z_C(condition, Treatment("control"))[T.congruent]
# <img src="data:image/png;base64,...">
# Plotting z_C(condition, Treatment("control"))[T.incongruent]
# <img src="data:image/png;base64,...">
# Plotting a_Intercept
# /home/leonardv/virtualenvs/np/lib/python3.4/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">
# ...

# %% [markdown]
# ## Audio ~ v

# %%
print(audio_v.dic)
audio_v.plot_posteriors('v_Intercept')
audio_v.plot_posteriors('v_C(condition, Treatment("control"))[T.congruent]')
audio_v.plot_posteriors('v_C(condition, Treatment("control"))[T.incongruent]')
audio_v.plot_posteriors('a_Intercept')
audio_v.plot_posteriors('z_Intercept')
audio_v.plot_posteriors('t_Intercept')
# Out:
# -30265.8827855
# Plotting v_Intercept
# /home/leonardv/virtualenvs/np/lib/python3.4/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.congruent]
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.incongruent]
# <img src="data:image/png;base64,...">
# Plotting a_Intercept
# <img src="data:image/png;base64,...">
# Plotting z_Intercept
# <img src="data:image/png;base64,...">
# Plotting t_Intercept
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Audio ~ v, z

# %%
print(audio_v_z.dic)
audio_v_z.plot_posteriors('v_Intercept')
audio_v_z.plot_posteriors('v_C(condition, Treatment("control"))[T.congruent]')
audio_v_z.plot_posteriors('v_C(condition, Treatment("control"))[T.incongruent]')
audio_v_z.plot_posteriors('a_Intercept')
audio_v_z.plot_posteriors('z_Intercept')
audio_v_z.plot_posteriors('z_C(condition, Treatment("control"))[T.congruent]')
audio_v_z.plot_posteriors('z_C(condition, Treatment("control"))[T.incongruent]')
audio_v_z.plot_posteriors('t_Intercept')
# Out:
# -43494.1952707
# Plotting v_Intercept
# /home/leonardv/virtualenvs/np/lib/python3.4/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.congruent]
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.incongruent]
# <img src="data:image/png;base64,...">
# Plotting a_Intercept
# <img src="data:image/png;base64,...">
# Plotting z_Intercept
# <img src="data:image/png;base64,...">
# Plotting z_C(condition, Treatment("control"))[T.congruent]
# <img src="data:image/png;base64,...">
# Plotting z_C(condition, Treatment("control"))[T.incongruent]
# ...

# %% [markdown]
# ## Audio ~ v, a, z

# %%
print(audio_v_a_z.dic)
audio_v_a_z.plot_posteriors('v_Intercept')
audio_v_a_z.plot_posteriors('v_C(condition, Treatment("control"))[T.congruent]')
audio_v_a_z.plot_posteriors('v_C(condition, Treatment("control"))[T.incongruent]')
audio_v_a_z.plot_posteriors('a_Intercept')
audio_v_a_z.plot_posteriors('a_C(condition, Treatment("control"))[T.congruent]')
audio_v_a_z.plot_posteriors('a_C(condition, Treatment("control"))[T.incongruent]')
audio_v_a_z.plot_posteriors('z_Intercept')
audio_v_a_z.plot_posteriors('z_C(condition, Treatment("control"))[T.congruent]')
audio_v_a_z.plot_posteriors('z_C(condition, Treatment("control"))[T.incongruent]')
audio_v_a_z.plot_posteriors('t_Intercept')
# Out:
# -42242.2071574
# Plotting v_Intercept
# /home/leonardv/virtualenvs/np/lib/python3.4/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.congruent]
# <img src="data:image/png;base64,...">
# Plotting v_C(condition, Treatment("control"))[T.incongruent]
# <img src="data:image/png;base64,...">
# Plotting a_Intercept
# <img src="data:image/png;base64,...">
# Plotting a_C(condition, Treatment("control"))[T.congruent]
# <img src="data:image/png;base64,...">
# Plotting a_C(condition, Treatment("control"))[T.incongruent]
# <img src="data:image/png;base64,...">
# Plotting z_Intercept
# ...
